# %%
# Import, read, and split data
import pandas as pd
data = pd.read_csv('data.csv')
import numpy as np
X = np.array(data[['x1', 'x2']])
y = np.array(data['y'])

# %%
data
# Out:
#           x1        x2    y
# 0   0.336494 -0.985951 -1.0
# 1  -0.011043 -0.105529  1.0
# 2   0.238160 -0.617417  1.0
# 3  -0.366783 -0.713819  1.0
# 4   1.221923 -1.039399 -1.0
# ..       ...       ...  ...
# 95 -1.457533 -1.306791 -1.0
# 96  1.635614  0.273943 -1.0
# 97  0.113120  0.020465  1.0
# 98  0.753405  0.193830  1.0
# 99 -0.538129 -0.000723  1.0
#
# [100 rows x 3 columns]

# %%
data[['x1', 'x2']]
# Out:
#           x1        x2
# 0   0.336494 -0.985951
# 1  -0.011043 -0.105529
# 2   0.238160 -0.617417
# 3  -0.366783 -0.713819
# 4   1.221923 -1.039399
# ..       ...       ...
# 95 -1.457533 -1.306791
# 96  1.635614  0.273943
# 97  0.113120  0.020465
# 98  0.753405  0.193830
# 99 -0.538129 -0.000723
#
# [100 rows x 2 columns]

# %%
data[['y']]
# Out:
#       y
# 0  -1.0
# 1   1.0
# 2   1.0
# 3   1.0
# 4  -1.0
# ..  ...
# 95 -1.0
# 96 -1.0
# 97  1.0
# 98  1.0
# 99  1.0
#
# [100 rows x 1 columns]

# %%
# Fix random seed
np.random.seed(55)

# %%
## Imports
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC

# %%
from sklearn.model_selection import learning_curve
from matplotlib import pyplot as plt

# It is good to randomize the data before drawing Learning Curves
def randomize(X, Y):
    permutation = np.random.permutation(Y.shape[0])
    X2 = X[permutation,:]
    Y2 = Y[permutation]
    return X2, Y2

# X2, y2 = randomize(X, y)

def draw_learning_curves(X, y, estimator, num_trainings):
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=None, n_jobs=1, train_sizes=np.linspace(.1, 1.0, num_trainings))

    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)

    plt.grid()

    plt.title("Learning Curves")
    plt.xlabel("Training examples")
    plt.ylabel("Score")

    plt.plot(train_scores_mean, 'o-', color="g",
             label="Training score")
    plt.plot(test_scores_mean, 'o-', color="y",
             label="Cross-validation score")


    plt.legend(loc="best")

    plt.show()

# %%
X_new, y_new = randomize(X, y)

# %%
# Logistic Regression
estimator1 = LogisticRegression()

draw_learning_curves(X_new, y_new, estimator1, num_trainings=73)

# %% [markdown]
# As you can see, we defined our curves with **Training and Testing Error** , and draw_learning_curve function defines them with **Training and Testing Score**.
#
# These are opposite, *so the higher the error, the lower the score.*

# %%
# Decision Tree
estimator2 = GradientBoostingClassifier()

draw_learning_curves(X_new, y_new, estimator2, num_trainings=73)

# %%
# Support Vector Machines
estimator3 = SVC(kernel='rbf', gamma=1000)

draw_learning_curves(X_new, y_new, estimator3, num_trainings=73)

# %% [markdown]
# # Theory
#
# ## High Bias - Underfitting
# ## High Variance - Overfitting

# %%
from IPython.display import Image
Image(filename='learning-curves.png')

# %%
from utils import plot_decision_boundaries

# Logistic Regression
plt.figure()
plt.title("Logistic Regression Boundary", fontsize=16)
plot_decision_boundaries(X_new, y_new, LogisticRegression)
plt.show()

# Decision Tree
plt.figure()
plt.title("Decision Tree Boundary", fontsize=16)
plot_decision_boundaries(X_new, y_new, GradientBoostingClassifier)
plt.show()

# SVM
plt.figure()
plt.title("SVM Boundary", fontsize=16)
plot_decision_boundaries(X_new, y_new, SVC)
plt.show()

# %% [markdown]
# * Logistic Regression Model is **Underfitting**
# * Decision Tree Model is the **Just Working**
# * Support Vector Machine Model is **Overfitting**
